# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
import pandas as pd

dados = {
    "Produto": ["Assistente virtual", "Mesa de jantar", "Jogo de tabuleiro", "Micro-ondas", "Cadeira de escritório"],
    "Categoria do Produto": ["eletronicos", "moveis", "brinquedos", "eletrodomesticos", "moveis"],
    "Preço": [219.08, 256.35, 279.51, 1009.99, 446.99],
    "Frete": [9.25, 11.23, 21.26, 54.66, 26.96],
    "Data da Compra": ["16/01/2021", "18/05/2022", "15/03/2021", "03/05/2022", "07/11/2020"],
    "Vendedor": ["Pedro Gomes", "Beatriz Moraes", "João Souza", "João Souza", "Larissa Alves"],
    "Local da compra": ["SP", "RJ", "DF", "RS", "MG"],
    "Avaliação da compra": [4, 1, 1, 4, 5],
    "Tipo de pagamento": ["cartao_credito", "cartao_credito", "cartao_credito", "boleto", "boleto"],
    "Quantidade de parcelas": [8, 4, 1, 1, 1],
    "lat": [-22.19, -22.25, -15.83, -30.17, -18.10],
    "lon": [-48.79, -42.66, -47.86, -53.50, -44.38]
}

# %%
df = pd.DataFrame(dados)

# Calculando o faturamento (só o valor dos produtos, sem considerar frete)
faturamento_total = df["Preço"].sum()
print(f"Faturamento total: R$ {faturamento_total:.2f}")
# Out:
# Faturamento total: R$ 2211.92

# %% [markdown]
# # 2. Vendas por Categoria

# %%
vendas_categoria = df["Categoria do Produto"].value_counts()

import matplotlib.pyplot as plt

# %%
vendas_categoria.plot(kind='bar', color='skyblue')
plt.title("Vendas por Categoria")
plt.xlabel("Categoria")
plt.ylabel("Quantidade de Vendas")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
media_avaliacao = df["Avaliação da compra"].mean()
print(f"Média de Avaliação da Loja: {media_avaliacao:.2f}")
# Out:
# Média de Avaliação da Loja: 3.00

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
contagem_produtos = df["Produto"].value_counts()

if contagem_produtos.nunique() == 1:
    print("Todos os produtos têm a mesma quantidade de vendas.")
else:
    produto_mais_vendido = contagem_produtos.idxmax()
    produto_menos_vendido = contagem_produtos.idxmin()
    print(f"Produto mais vendido: {produto_mais_vendido}")
    print(f"Produto menos vendido: {produto_menos_vendido}")
# Out:
# Todos os produtos têm a mesma quantidade de vendas.

# %%
plt.figure(figsize=(10,5))
vendas_por_produto.plot(kind='line', marker='o', color='orange')

plt.title("Vendas por Produto - Gráfico de Linhas")
plt.xlabel("Produto")
plt.ylabel("Quantidade de Vendas")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_medio = df["Frete"].mean()
print(f"Frete médio: R$ {frete_medio:.2f}")
# Out:
# Frete médio: R$ 24.67

# %% [markdown]
# Relatório de Análise de Vendas e Desempenho das Lojas
#
# Este relatório tem como objetivo ajudar o Sr. João a decidir qual loja vender para investir em um novo negócio. Para isso, foram analisadas as seguintes métricas:
# - Faturamento Total de Cada Loja
# - Vendas por Categoria de Produto
# - Média de Avaliação dos Clientes
# - Produtos Mais e Menos Vendidos
# - Custo Médio do Frete
#
# Com essas informações, o Sr. João poderá tomar uma decisão informada.
#
# 2. Análise do Faturamento
# O faturamento total de cada loja foi calculado a partir do preço de cada produto vendido. Esse valor é essencial para entender o impacto das vendas nas finanças de cada loja.
#
# 3. Vendas por Categoria
# A análise das vendas por categoria mostra a quantidade de vendas em diferentes categorias de produtos. O gráfico abaixo ilustra a distribuição de vendas entre as categorias.
#
# Gráfico de Vendas por Categoria
# - Categoria com Mais Vendas**: Eletrodomésticos
# - Categoria com Menos Vendas**: Brinquedos
#
#  4. Média de Avaliação das Lojas
# A média de avaliação das lojas foi de (3.00), o que indica que, em média, os clientes não estão completamente satisfeitos com as compras realizadas. Isso sugere que pode haver margem para melhorias nas lojas.
#
#  5. Produtos Mais e Menos Vendidos
# Analisando a quantidade de vendas por produto, podemos observar que todos os produtos possuem o mesmo número de vendas, o que não nos permite destacar um produto como mais ou menos vendido neste conjunto de dados.
#
# - Produto Mais Vendido: Todos os produtos têm o mesmo número de vendas (1 venda cada).
# - Produto Menos Vendido: Todos os produtos têm o mesmo número de vendas (1 venda cada).
#
#  6. Frete Médio por Loja
# O frete médio por loja foi calculado com base no custo do frete de cada produto. O valor médio de frete para todas as lojas é de (R$ 24.67). Este é um dado importante, pois o custo do frete pode impactar diretamente o preço final dos produtos e, consequentemente, a satisfação dos clientes.
#
# 7. Conclusão e Recomendação
# - Desempenho Geral: Todas as lojas possuem um desempenho relativamente equilibrado, com poucas variações nas métricas analisadas.
#
# - Satisfação do Cliente: A média de avaliação das lojas sugere que o Sr. João poderia melhorar a experiência do cliente para aumentar a satisfação.
#
# - Decisão de Venda: Baseado nas análises de faturamento, categorias e satisfação do cliente, o Sr. João pode optar por vender a loja com menor desempenho em vendas. Se a loja com menor número de vendas for confirmada, essa loja será a mais indicada para ser vendida e permitir o investimento em um novo negócio.

# %%
import matplotlib.pyplot as plt


vendas_por_produto = df["Produto"].value_counts()


plt.figure(figsize=(6,6))
vendas_por_produto.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])


plt.title("Distribuição de Vendas por Produto")
plt.ylabel("")
plt.show()
